# %%
import pandas as pd

# %% [markdown]
# ## Loading the data
#
# Generating a data frame from the csv Shark Attacks

# %%
#ande están los datos? cómo los convertimos en la principal estructura de los pandas - un dataframe?
sharks = pd.read_csv("/Users/blancurri/Desktop/Formació/IronHack/Projects/PR02-project-pandas/attacks.csv",encoding = 'latin-1', parse_dates=['Date'])

# %% [markdown]
# ## Previewing the data
# Getting familiar with the information

# %%
#qué tipo de estructura de datos estamos tratando?
type(sharks)
# Out:
# pandas.core.frame.DataFrame

# %%
#qué tipo de datos tenemos en el dataframe?
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
# Conclusiones iniciales:
# - Todas las columnas tienen entre un 75% y un 50% de datos nulos
# - Hay columnas (de la 16 a la 23) cuyo propósito no está claro
# - El formato de la mayoría de las columnas es object

# %%
#qué dimensiones tiene el df?
sharks.shape
# Out:
# (25723, 24)

# %%
#qué tal pintan las primeras filas del df?
sharks.head(50)
# Out:
#      Case Number                  Date    Year          Type        Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating            USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked            USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid            USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked         MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked         BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked            USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked            USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked            USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked      AUSTRALIA
# ...

# %%
#muéstrame una selección de datos random:
sharks.sample(50)
# Out:
#         Case Number                  Date    Year        Type       Country  \
# 3076     1980.01.13           13-Jan-1980  1980.0  Unprovoked  SOUTH AFRICA
# 16829           NaN                   NaN     NaN         NaN           NaN
# 6153     1755.00.00                  1755  1755.0  Unprovoked        SWEDEN
# 1287     2008.02.24           24-Feb-2008  2008.0  Unprovoked       BAHAMAS
# 1809   2002.11.28.a           28-Nov-2002  2002.0  Unprovoked           USA
# 12179           NaN                   NaN     NaN         NaN           NaN
# 4764   1940.07.13.a           13-Jul-1940  1940.0  Unprovoked           USA
# 21987           NaN                   NaN     NaN         NaN           NaN
# 21183           NaN                   NaN     NaN         NaN           NaN
# 11074           NaN                   NaN     NaN         NaN           NaN
# 16954           NaN                   NaN     NaN         NaN           NaN
# ...

# %%
#qué columnas tenemos?
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#qué cantidad de valores válidos tenemos por columna?
sharks.count()
# Out:
# Case Number               8702
# Date                      6302
# Year                      6300
# Type                      6298
# Country                   6252
# Area                      5847
# Location                  5762
# Activity                  5758
# Name                      6092
# Sex                       5737
# Age                       3471
# Injury                    6274
# Fatal (Y/N)               5763
# Time                      2948
# Species                   3464
# Investigator or Source    6285
# pdf                       6302
# href formula              6301
# href                      6302
# Case Number.1             6302
# Case Number.2             6302
# original order            6309
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %%
#qué nos ha dado por índice predeterminado?
sharks.index
# Out:
# RangeIndex(start=0, stop=25723, step=1)

# %%
#cuántos valores únicos hay por columna?
sharks.nunique()
# Out:
# Case Number               6287
# Date                      5433
# Year                       249
# Type                         8
# Country                    212
# Area                       825
# Location                  4108
# Activity                  1532
# Name                      5230
# Sex                          6
# Age                        157
# Injury                    3737
# Fatal (Y/N)                  8
# Time                       366
# Species                   1549
# Investigator or Source    4969
# pdf                       6291
# href formula              6290
# href                      6285
# Case Number.1             6285
# Case Number.2             6286
# original order            6308
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %% [markdown]
# ## Initial - draft questions to inspect the data
#
# - What is the country with more provocked attacks? (5 points)
# - What is the gender distribution of shark attacks? (5 points)
# - Are there more attacks when water is calmed or moving? (50 points)
# - Splitting countries by hemisphere and its seasons, what is the most active attack season? (250 points)

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# ### Trimming our dataframe
# We have seen there are so many null values in the most interesting columns that we will prioritise reshaping our dataframe

# %%
#Vamos a ver cuántos nulos hay por columna:
sharks.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
#La mayor parte de la columnas tienen como mínimo el 50% de datos nulos, así que... vamos a dejar caer las columnas menos interesantes:
re_sharks = sharks.filter(['Date','Type','Country', "Activity", "Sex ", "Fatal (Y/N)"], axis=1)
re_sharks.sample(15)
# Out:
#               Date        Type       Country  \
# 3137   12-Nov-1977    Provoked  SOUTH AFRICA
# 19309          NaN         NaN           NaN
# 685    13-Apr-2013  Unprovoked          GUAM
# 11787          NaN         NaN           NaN
# 23955          NaN         NaN           NaN
# 12915          NaN         NaN           NaN
# 6064          1842  Unprovoked     AUSTRALIA
# 4068   20-Aug-1959     Invalid   PHILIPPINES
# 4103   29-Mar-1959  Unprovoked           USA
# 2715   13-Sep-1988  Unprovoked           USA
# 4542   19-Aug-1948  Unprovoked          IRAN
# 23724          NaN         NaN           NaN
# 11466          NaN         NaN           NaN
# 9321           NaN         NaN           NaN
# 21630          NaN         NaN           NaN
#
#                                                 Activity Sex  Fatal (Y/N)
# 3137                                            Standing    M           N
# 19309                                                NaN  NaN         NaN
# ...

# %%
#La columna "Sex" tiene un espacio blanco, vamos a renombrarla:
re_sharks.rename(columns={"Sex ":"Sex"}, inplace=True)
re_sharks.columns
# Out:
# Index(['Date', 'Type', 'Country', 'Activity', 'Sex', 'Fatal (Y/N)'], dtype='object')

# %%
#y ahora dejamos caer las filas duplicadas:
reshaped_sharks = re_sharks.drop_duplicates()
reshaped_sharks.shape
# Out:
# (6204, 6)

# %%
#Hemos pasado de 25723 filas a 5301... un 20% de la tabla original :)
reshaped_sharks.sample(15)
# Out:
#                                   Date          Type              Country  \
# 798                        19-Apr-2012    Unprovoked                  USA
# 4477                       09-Apr-1950    Unprovoked         SOUTH AFRICA
# 5430                       21-Sep-1908    Unprovoked            AUSTRALIA
# 4856                       04-Feb-1937       Boating            AUSTRALIA
# 980                        09-Oct-2010    Unprovoked            AUSTRALIA
# 3633                       23-Mar-1965       Invalid                  USA
# 4528                              1949    Unprovoked           NEW GUINEA
# 5189                       08-Feb-1924       Invalid            AUSTRALIA
# 1140                       03-Apr-2009    Unprovoked                  USA
# 2976                       01-Jul-1982    Unprovoked                  USA
# 5513                              1904    Unprovoked       REUNION ISLAND
# 1606                       10-Mar-2005       Invalid         SOUTH AFRICA
# ...

# %%
#Renombramos el df por comodidad y miramos cuántos elementos únicos contiene
df = reshaped_sharks

# %% [markdown]
# ### Formatting the "Countries" column

# %%
#Quiero ver las entradas de países para ver si hay repetidos o mal escritos
df.groupby("Country").count()
# Out:
#                    Date  Type  Activity  Sex  Fatal (Y/N)
# Country
#  PHILIPPINES          1     1         1    1            1
#  TONGA                3     3         3    3            3
# ADMIRALTY ISLANDS     1     1         0    1            1
# AFRICA                1     1         1    1            1
# ALGERIA               1     1         1    1            1
# ...                 ...   ...       ...  ...          ...
# VIETNAM              15    14        12   15           15
# WEST INDIES           2     2         2    2            2
# WESTERN SAMOA         1     1         1    1            1
# YEMEN                 2     2         2    1            2
# YEMEN                 7     7         7    6            6
#
# [212 rows x 5 columns]

# %%
df['Country'].duplicated().any()
# Out:
# True

# %%
countriesrepes = df['Country'].duplicated() 
countriesrepes
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 6298     True
# 6299     True
# 6300     True
# 6301    False
# 6302     True
# Name: Country, Length: 6204, dtype: bool

# %%
df.groupby("Country").count().sort_values("Sex",ascending = False).head(10).plot(kind = "barh")

# %%
#Nos quedamos con los top 3 countries para nuestros 
df = df[(df.Country == "USA") | (df.Country == "AUSTRALIA") | (df.Country == "SOUTH AFRICA")]

# %%
df
# Out:
#              Date        Type    Country      Activity Sex Fatal (Y/N)
# 0     25-Jun-2018     Boating        USA      Paddling   F           N
# 1     18-Jun-2018  Unprovoked        USA      Standing   F           N
# 2     09-Jun-2018     Invalid        USA       Surfing   M           N
# 3     08-Jun-2018  Unprovoked  AUSTRALIA       Surfing   M           N
# 5     03-Jun-2018  Unprovoked  AUSTRALIA  Kite surfing   M           N
# ...           ...         ...        ...           ...  ..         ...
# 6293  Before 1906  Unprovoked  AUSTRALIA       Fishing   M           Y
# 6296  Before 1906  Unprovoked  AUSTRALIA      Swimming   M           Y
# 6297  Before 1903  Unprovoked  AUSTRALIA        Diving   M           Y
# 6298  Before 1903  Unprovoked  AUSTRALIA  Pearl diving   M           Y
# 6299    1900-1905  Unprovoked        USA      Swimming   M           Y
#
# [4077 rows x 6 columns]

# %%
df.groupby("Country").count().sort_values("Sex",ascending = False).head(10).plot(kind = "barh")

# %% [markdown]
# ### Formatting the "Sex" column

# %%
df.groupby("Sex").count()
# Out:
#      Date  Type  Country  Activity  Fatal (Y/N)
# Sex
# F     445   445      445       408          402
# M    3328  3327     3328      3146         3044
# M       2     2        2         2            2
# N       1     1        1         1            1
# lli     1     1        1         1            1

# %%
#Por qué hay dos filas cuyo género es "M" pero me lo cuenta como si fuera diferente?
df = df[(df["Sex"] == "F") | (df["Sex"] == "M")]
df.groupby("Sex").count()
# Out:
#      Date  Type  Country  Activity  Fatal (Y/N)
# Sex
# F     445   445      445       408          402
# M    3328  3327     3328      3146         3044

# %%
df.groupby("Sex").count().plot(kind = "barh")

# %% [markdown]
# ### Formatting the "Type" column

# %%
#Vamos a ver los datos únicos que hay en Type para hacernos una idea de cómo está distribuído 
df["Type"].describe()
# Out:
# count           3772
# unique             7
# top       Unprovoked
# freq            2936
# Name: Type, dtype: object

# %%
df["Type"].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        nan, 'Boat', 'Sea Disaster'], dtype=object)

# %%
#Miramos qué tipos de ataques ha habido y su incidencia
df.groupby("Type").count()
# Out:
#               Date  Country  Activity   Sex  Fatal (Y/N)
# Type
# Boat            18       18        16    18           18
# Boating         71       71        70    71           71
# Invalid        339      339       278   339           16
# Provoked       352      352       336   352          352
# Questionable     2        2         2     2            2
# Sea Disaster    54       54        52    54           53
# Unprovoked    2936     2936      2799  2936         2934

# %%
#Tenemos un par de outliers feos: Questionable y Boatomg
df[ (df["Type"] == "Questionable") | (df["Type"] == "Boatomg") ]
# Out:
#            Date          Type    Country Activity Sex Fatal (Y/N)
# 16  09-May-2018  Questionable  AUSTRALIA  Surfing   M           N
# 20  25-Apr-2018  Questionable  AUSTRALIA  Surfing   M           N

# %%
df.shape
# Out:
# (3773, 6)

# %%
#Queremos desprendernos de Questionable y Boatomg
df = df[df.Type != "Questionable"]
df = df[df.Type != "Boatomg"]
df.shape
# Out:
# (3771, 6)

# %%
#Queremos que las filas con "Boat" y "Boating" se agrupen, así que vamos a cambiar el type de Boat a Boating
df.Type.replace("Boat", "Boating", inplace = True)

# %%
#Creo que el cambio no se cambia
df.groupby("Type").count()
# Out:
#               Date  Country  Activity   Sex  Fatal (Y/N)
# Type
# Boating         89       89        86    89           89
# Invalid        339      339       278   339           16
# Provoked       352      352       336   352          352
# Sea Disaster    54       54        52    54           53
# Unprovoked    2936     2936      2799  2936         2934

# %%
df.groupby("Type").count().plot(kind = "barh")

# %% [markdown]
# ### Formatting the "Activity" column

# %%
df.head()
# Out:
#           Date        Type    Country      Activity Sex Fatal (Y/N)
# 0  25-Jun-2018     Boating        USA      Paddling   F           N
# 1  18-Jun-2018  Unprovoked        USA      Standing   F           N
# 2  09-Jun-2018     Invalid        USA       Surfing   M           N
# 3  08-Jun-2018  Unprovoked  AUSTRALIA       Surfing   M           N
# 5  03-Jun-2018  Unprovoked  AUSTRALIA  Kite surfing   M           N

# %%
#vamos a ver los valores únicos que hay en la columna activity y su proporción. Éstos son los top 15:
df.Activity.value_counts(ascending=False).head(15)
# Out:
# Surfing           795
# Swimming          534
# Fishing           201
# Spearfishing      166
# Wading            126
# Bathing            85
# Standing           81
# Diving             56
# Snorkeling         49
# Scuba diving       46
# Body surfing       44
# Body boarding      43
# Swimming           33
# Treading water     30
# Kayaking           28
# Name: Activity, dtype: int64

# %%
#Cuenta registros de cada tipo de activity, estamos viendo los 10 más a menudo
df.groupby("Activity").count().sort_values(["Date"], ascending=False).head(10)
# Out:
#               Date  Type  Country  Sex  Fatal (Y/N)
# Activity
# Surfing        795   794      795  795          764
# Swimming       534   534      534  534          475
# Fishing        201   201      201  201          191
# Spearfishing   166   166      166  166          149
# Wading         126   126      126  126          118
# Bathing         85    85       85   85           76
# Standing        81    81       81   81           80
# Diving          56    56       56   56           48
# Snorkeling      49    49       49   49           48
# Scuba diving    46    46       46   46           39

# %%
df.groupby("Activity").count().sort_values(["Date"], ascending=False).head(10).plot(kind = "barh")

# %% [markdown]
# ### Formatting the  "Date" column

# %% [markdown]
# #### Formatting column "Date" from "object" format to a "datetime" format

# %%
#Vamos a inspeccionar la columna "Date"
df["Date"].describe()
# Out:
# count            3771
# unique           3448
# top       05-Oct-2003
# freq                5
# Name: Date, dtype: object

# %%
from datetime import datetime

# %%
#Sabemos que el datatype de Date es object y lo queremos cambiar a date

#Opción 1: df["Date"] = df["Date"].astype("date")
#Opción 2: df['Date']=pd.to_datetime(df['Date'])

#Ninguna funciona! :)

# %%
#Objetivo: convertir las fechas al formato Mmm-YYYY
#Cómo: 1. Quitar todo el texto que no sea fecha própiamente dicho
# Remove any text that is not DD-Mmm-YYYY
# Remove any date from before 1950
# Remove any date that doesn't contain month and year

# %%
#Hemos creado el df al inicio con el "parse_dates=['DATE']" para trabajar bien la columna de fechas


#Los datos de la columna "Date" están en muuuuchos formatos diferentes... soltaremos los que no tienen DD-Mmm-YYYY



#Sabemos que "Date" tiene formato "object", vamos a convertirlo a datetime64 con astype
#No ha funcionado, así que pasaremos a dividir esa columna en tres columnas 

#Tampoco me ha funcionado coger la columna y convertirla directamente con pd.to_datetime format
#df['DATE']=pd.to_datetime(df['DATE'])
#reshaped_sharks["Date"] = pd.to_datetime(reshaped_sharks["Date"])

# %%
#from datetime import datetime
#df = pd.DataFrame({'Date':['25-Jun-2018']})
#from functools import partial
#to_datetime = partial(pd.to_datetime, format='%d-%b-%Y')
#reshaped_sharks['Date'] = reshaped_sharks['Date'].apply(to_datetime)
#reshaped_sharks.dtypes

# %%
pd.unique(df["Year"])
# Out:
# ----------------------
# KeyErrorTraceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyErrorTraceback (most recent call last)
# <ipython-input-314-ca244263126d> in <module>
# ----> 1 pd.unique(df["Year"])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
# ...

# %% [markdown]
# ## Explore the data:
#
# Visualicemos qué conclusiones podemos sacar de los datos limpitos

# %%
df.Activity.hist()
# Out:
# /Users/blancurri/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 150 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/blancurri/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/blancurri/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/blancurri/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/blancurri/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 150 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %% [markdown]
# - What is the country with more provocked attacks? (5 points)

# %%
FatalityTotal = df.T
