# %% [markdown]
# # Importing libaries and data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/Júlia/Documents/Ironhack/modulo_1/Proyectos/PR02-project-pandas/attacks.csv')

# %%
df.head(5)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# # Observing the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
with pd.option_context('display.max_rows', 10, 'display.max_columns', None): 
    display(df)
#Checking all the columns
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# # Dropping missing data and duplicates

# %%
df.dropna(how='all', thresh=3, inplace=True)
#Dropping all the rows that have more than 3 missing values

# %%
df.shape
# Out:
# (6302, 24)

# %%
df.drop_duplicates(subset='original order', inplace=True)
#we use original order as a reference since all its values must be unique

# %%
df.shape
# Out:
# (6301, 24)

# %%
df.drop_duplicates(subset='Case Number', inplace=True)
#we clean it further by checking duplicate case numbers

# %%
df.shape
# Out:
# (6285, 24)

# %% [markdown]
# # Setting the original order as the index

# %%
df['original order'] = df['original order'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6285 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6284 non-null   object
#  1   Date                    6285 non-null   object
#  2   Year                    6283 non-null   float64
#  3   Type                    6281 non-null   object
#  4   Country                 6235 non-null   object
#  5   Area                    5831 non-null   object
#  6   Location                5745 non-null   object
#  7   Activity                5743 non-null   object
#  8   Name                    6076 non-null   object
#  9   Sex                     5721 non-null   object
#  10  Age                     3465 non-null   object
#  11  Injury                  6257 non-null   object
#  12  Fatal (Y/N)             5750 non-null   object
#  13  Time                    2944 non-null   object
# ...

# %%
df.set_index('original order', inplace=True)

# %%
df.head()
# Out:
#                Case Number         Date    Year        Type    Country  \
# original order
# 6303            2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 6302            2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 6301            2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 6300            2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 6299            2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
#
#                            Area                        Location     Activity  \
# original order
# 6303                 California     Oceanside, San Diego County     Paddling
# 6302                    Georgia  St. Simon Island, Glynn County     Standing
# 6301                     Hawaii                    Habush, Oahu      Surfing
# 6300            New South Wales              Arrawarra Headland      Surfing
# 6299                     Colima                        La Ticla  Free diving
#
# ...

# %%
df.sort_index(ascending = False, inplace = True)

# %% [markdown]
# # Cleaning the Country column

# %%
countries = dict(df['Country'].value_counts())
#we create a dictionary to check the full list of unique values more easily

# %%
sorted(countries.items())
#we sort them by alphabetical order
# Out:
# [(' PHILIPPINES', 1),
#  (' TONGA', 3),
#  ('ADMIRALTY ISLANDS', 1),
#  ('AFRICA', 1),
#  ('ALGERIA', 1),
#  ('AMERICAN SAMOA', 3),
#  ('ANDAMAN / NICOBAR ISLANDAS', 1),
#  ('ANDAMAN ISLANDS', 1),
#  ('ANGOLA', 1),
#  ('ANTIGUA', 2),
#  ('ARGENTINA', 1),
#  ('ARUBA', 1),
#  ('ASIA?', 1),
#  ('ATLANTIC OCEAN', 17),
#  ('AUSTRALIA', 1336),
#  ('AZORES', 5),
#  ('BAHAMAS', 109),
#  ('BAHREIN', 1),
#  ('BANGLADESH', 1),
#  ('BARBADOS', 6),
#  ('BAY OF BENGAL', 1),
#  ('BELIZE', 3),
#  ('BERMUDA', 16),
#  ('BRAZIL', 112),
#  ('BRITISH ISLES', 1),
#  ('BRITISH NEW GUINEA', 1),
#  ('BRITISH VIRGIN ISLANDS', 1),
#  ('BRITISH WEST INDIES', 1),
#  ('BURMA', 4),
#  ('Between PORTUGAL & INDIA', 1),
#  ('CANADA', 12),
#  ('CAPE VERDE', 3),
#  ('CARIBBEAN SEA', 8),
#  ('CAYMAN ISLANDS', 2),
#  ('CENTRAL PACIFIC', 2),
#  ('CEYLON', 3),
#  ('CEYLON (SRI LANKA)', 1),
#  ('CHILE', 8),
#  ('CHINA', 6),
#  ('COLUMBIA', 9),
#  ('COMOROS', 1),
#  ('COOK ISLANDS', 1),
#  ('COSTA RICA', 17),
# ...

# %%
df['Country'] = df['Country'].astype('str')

# %%
df['Country'] = df['Country'].fillna('UNKNOWN')

# %%
df.replace({'UNITED ARAB EMIRATES (UAE)':'UNITED ARAB EMIRATES'}, inplace=True)
# We try different methods to replace the values. Here we replace manually with replace

# %%
df[df['Country'].apply(lambda x: 'UNITED ARAB EMIRATES' in x)]
#we check that it has been corrected
# Out:
#                  Case Number                  Date    Year        Type  \
# original order
# 6161              2017.05.12           12-May-2017  2017.0  Unprovoked
# 5988            2016.01.24.a           24-Jan-2016  2016.0     Boating
# 5377            2011.05.07.R  Reported 07-May-2011  2011.0     Invalid
# 5254            2010.01.22.b           22-Jan-2010  2010.0  Unprovoked
#
#                              Country                      Area  \
# original order
# 6161            UNITED ARAB EMIRATES                 Sharjah,
# 5988            UNITED ARAB EMIRATES          Fujairah Emirate
# 5377            UNITED ARAB EMIRATES  Umm al Qaywayan Province
# 5254            UNITED ARAB EMIRATES                     Dubai
#
#                                Location      Activity  \
# original order
# 6161                        Khor Fakkan  Spearfishing
# 5988              35 miles off Fujairah       Fishing
# 5377                       Khor Fakkan       Fishing
# ...

# %%
df['Country'] = df['Country'].str.replace('YEMEN ', 'YEMEN').str.replace(' PHILIPPINES', 'PHILIPPINES').str.replace(' TONGA', 'TONGA').str.replace('ANDAMAN / NICOBAR ISLANDAS', 'ANDAMAN ISLANDS').str.replace('BRITISH ISLES', 'UNITED KINGDOM').str.replace('BRITISH NEW GUINEA', 'PAPUA NEW GUINEA').str.replace('BRITISH WEST INDIES', 'CARIBBEAN SEA').str.replace('WEST INDIES', 'CARIBBEAN SEA').str.replace('CEYLON', 'SRI LANKA').str.replace('CEYLON (SRI LANKA)', 'SRI LANKA', regex = False).str.replace('CRETE', 'GREECE').str.replace('EGYPT ', 'EGYPT').str.replace('EGYPT / ISRAEL', 'EGYPT', regex = False).str.replace('ENGLAND', 'UNITED KINGDOM').str.replace('FEDERATED STATES OF MICRONESIA', 'MICRONESIA').str.replace('Fiji', 'FIJI').str.replace('IRAN / IRAQ', 'IRAN').str.replace('ITALY / CROATIA', 'ITALY').str.replace('MALDIVE ISLANDS', 'MALDIVES').str.replace('MEXICO ', 'MEXICO').str.replace('MID ATLANTIC OCEAN', 'ATLANTIC OCEAN').str.replace('NORTH ATLANTIC OCEAN ', 'ATLANTIC OCEAN').str.replace('NORTH ATLANTIC OCEAN', 'ATLANTIC OCEAN').str.replace('MID-PACIFC OCEAN', 'PACIFIC OCEAN').str.replace('PACIFIC OCEAN ', 'PACIFIC OCEAN').str.replace('SOUTH PACIFIC OCEAN', 'PACIFIC OCEAN').str.replace('SOUTHWEST PACIFIC OCEAN', 'PACIFIC OCEAN').str.replace('NICARAGUA ', 'NICARAGUA').str.replace('OKINAWA', 'JAPAN').str.replace('RED SEA / INDIAN OCEAN', 'RED SEA').str.replace('RED SEA?', 'RED SEA', regex=False).str.replace('REUNION ISLAND', 'REUNION').str.replace('ROATAN', 'HONDURAS').str.replace('SAN DOMINGO', 'DOMINICAN REPUBLIC').str.replace('SOLOMON ISLANDS / VANUATU', 'SOLOMON ISLANDS').str.replace('SUDAN?', 'SUDAN', regex = False).str.replace('ST. MAARTIN', 'ST. MARTIN').str.replace('SOUTH CHINA SEA', 'CHINA').str.replace('INDIAN OCEAN?', 'INDIAN OCEAN', regex = False).str.replace('NORTH PACIFIC OCEAN', 'PACIFIC OCEAN').str.replace('SOUTH ATLANTIC OCEAN', 'ATLANTIC OCEAN').str.replace('ASIA?', 'UNKNOWN', regex = False).str.replace('Between PORTUGAL & INDIA', 'UNKNOWN', regex = False).str.replace('Coast of AFRICA', 'UNKNOWN', regex = False).str.replace('EQUATORIAL GUINEA / CAMEROON', 'EQUATORIAL GUINEA', regex = False).str.replace('EGYPT/ ISRAEL', 'EGYPT').str.replace('DIEGO GARCIA', 'UNKNOWN')
#We replace all the values that have errors. This could have been done more easily with OpenRefine (we'll use it later)
# Out:
# <ipython-input-25-15a28a748114>:1: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
df.Country.value_counts()
# Out:
# USA                 2222
# AUSTRALIA           1336
# SOUTH AFRICA         576
# PAPUA NEW GUINEA     135
# NEW ZEALAND          127
#                     ...
# GULF OF ADEN           1
# GEORGIA                1
# SLOVENIA               1
# IRELAND                1
# KOREA                  1
# Name: Country, Length: 169, dtype: int64

# %%
countries = dict(df['Country'].value_counts())

# %%
#we check them again and see there are still some errors
sorted(countries.items())
# Out:
# [('ADMIRALTY ISLANDS', 1),
#  ('AFRICA', 1),
#  ('ALGERIA', 1),
#  ('AMERICAN SAMOA', 3),
#  ('ANDAMAN ISLANDS', 2),
#  ('ANGOLA', 1),
#  ('ANTIGUA', 2),
#  ('ARGENTINA', 1),
#  ('ARUBA', 1),
#  ('ATLANTIC OCEAN', 39),
#  ('AUSTRALIA', 1336),
#  ('AZORES', 5),
#  ('BAHAMAS', 109),
#  ('BAHREIN', 1),
#  ('BANGLADESH', 1),
#  ('BARBADOS', 6),
#  ('BAY OF BENGAL', 1),
#  ('BELIZE', 3),
#  ('BERMUDA', 16),
#  ('BRAZIL', 112),
#  ('BRITISH VIRGIN ISLANDS', 1),
#  ('BURMA', 4),
#  ('CANADA', 12),
#  ('CAPE VERDE', 3),
#  ('CARIBBEAN SEA', 11),
#  ('CAYMAN ISLANDS', 2),
#  ('CENTRAL PACIFIC', 2),
#  ('CHILE', 8),
#  ('CHINA', 7),
#  ('COLUMBIA', 9),
#  ('COMOROS', 1),
#  ('COOK ISLANDS', 1),
#  ('COSTA RICA', 17),
#  ('CROATIA', 34),
#  ('CUBA', 46),
#  ('CURACAO', 1),
#  ('CYPRUS', 1),
#  ('DJIBOUTI', 1),
#  ('DOMINICAN REPUBLIC', 8),
#  ('ECUADOR', 9),
#  ('EGYPT', 41),
#  ('EL SALVADOR', 4),
#  ('EQUATORIAL GUINEA', 1),
#  ('FALKLAND ISLANDS', 1),
#  ('FIJI', 65),
#  ('FRANCE', 13),
# ...

# %%
df['Country'].fillna('UNKNOWN')
# Out:
# original order
# 6303                      USA
# 6302                      USA
# 6301                      USA
# 6300                AUSTRALIA
# 6299                   MEXICO
#                 ...
# 6                   AUSTRALIA
# 5                   AUSTRALIA
# 4                         USA
# 3                      PANAMA
# 2       SRI LANKA (SRI LANKA)
# Name: Country, Length: 6285, dtype: object

# %%
df['Country'] = df['Country'].str.replace('nan', 'UNKNOWN', regex = False).str.replace('SRI LANKA (SRI LANKA)', 'SRI LANKA', regex = False)
#we clean the remaining errors

# %%
df['Country'] = df['Country'].str.upper()
#we set them all to uppercase for consistency

# %%
countries = dict(df['Country'].value_counts())

# %%
sorted(countries.items())
#last check to see they are all OK
# Out:
# [('ADMIRALTY ISLANDS', 1),
#  ('AFRICA', 1),
#  ('ALGERIA', 1),
#  ('AMERICAN SAMOA', 3),
#  ('ANDAMAN ISLANDS', 2),
#  ('ANGOLA', 1),
#  ('ANTIGUA', 2),
#  ('ARGENTINA', 1),
#  ('ARUBA', 1),
#  ('ATLANTIC OCEAN', 39),
#  ('AUSTRALIA', 1336),
#  ('AZORES', 5),
#  ('BAHAMAS', 109),
#  ('BAHREIN', 1),
#  ('BANGLADESH', 1),
#  ('BARBADOS', 6),
#  ('BAY OF BENGAL', 1),
#  ('BELIZE', 3),
#  ('BERMUDA', 16),
#  ('BRAZIL', 112),
#  ('BRITISH VIRGIN ISLANDS', 1),
#  ('BURMA', 4),
#  ('CANADA', 12),
#  ('CAPE VERDE', 3),
#  ('CARIBBEAN SEA', 11),
#  ('CAYMAN ISLANDS', 2),
#  ('CENTRAL PACIFIC', 2),
#  ('CHILE', 8),
#  ('CHINA', 7),
#  ('COLUMBIA', 9),
#  ('COMOROS', 1),
#  ('COOK ISLANDS', 1),
#  ('COSTA RICA', 17),
#  ('CROATIA', 34),
#  ('CUBA', 46),
#  ('CURACAO', 1),
#  ('CYPRUS', 1),
#  ('DJIBOUTI', 1),
#  ('DOMINICAN REPUBLIC', 8),
#  ('ECUADOR', 9),
#  ('EGYPT', 41),
#  ('EL SALVADOR', 4),
#  ('EQUATORIAL GUINEA', 1),
#  ('FALKLAND ISLANDS', 1),
#  ('FIJI', 65),
#  ('FRANCE', 13),
# ...

# %% [markdown]
# # Cleaning the Sex column

# %%
df.rename(columns = {'Sex ':'Sex'}, inplace = True)
#renaming to avoid mistakes if we don't type the whitespace

# %%
df['Sex'].value_counts()
# Out:
# M      5081
# F       634
# N         2
# M         2
# .         1
# lli       1
# Name: Sex, dtype: int64

# %%
df['Sex'] = df['Sex'].astype('str')

# %%
df['Sex'].fillna('Unknown', inplace = True)

# %%
df['Sex'].value_counts()
# Out:
# M      5081
# F       634
# nan     564
# N         2
# M         2
# .         1
# lli       1
# Name: Sex, dtype: int64

# %%
df['Sex'] = df['Sex'].str.replace('M ', 'M').str.replace('N', 'Unknown').str.replace('lli', 'Unknown').str.replace('nan', 'Unknown').str.replace('.', 'Unknown')
# Out:
# <ipython-input-39-f7210a5c42f2>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Sex'] = df['Sex'].str.replace('M ', 'M').str.replace('N', 'Unknown').str.replace('lli', 'Unknown').str.replace('nan', 'Unknown').str.replace('.', 'Unknown')

# %%
df['Sex'].value_counts()
# Out:
# M          5083
# F           634
# Unknown     568
# Name: Sex, dtype: int64

# %% [markdown]
# # Cleaning the Fatal column

# %%
df.rename(columns = {'Fatal (Y/N)':'Fatal'}, inplace = True)
#renaming to make it easier to work with

# %%
df['Fatal'].fillna('Unknown', inplace=True)

# %%
df['Fatal'].value_counts()
# Out:
# N          4284
# Y          1384
# Unknown     535
# UNKNOWN      71
#  N            7
# N             1
# y             1
# 2017          1
# M             1
# Name: Fatal, dtype: int64

# %%
df['Fatal'] = df['Fatal'].str.upper()

# %%
df['Fatal'] = df['Fatal'].str.replace(' N', 'N').str.replace('N ', 'N').str.replace('2017', 'UNKNOWN').str.replace('M', 'UNKNOWN')

# %%
df['Fatal'].value_counts()
# Out:
# N          4292
# Y          1385
# UNKNOWN     608
# Name: Fatal, dtype: int64

# %% [markdown]
# # Cleaning the Age column

# %%
df['Age'].describe()
# Out:
# count     3465
# unique     157
# top         17
# freq       154
# Name: Age, dtype: object

# %%
df['Age'].value_counts()
# Out:
# 17             154
# 18             150
# 19             142
# 20             141
# 15             139
#               ...
# ?    &   14      1
# 87               1
# 30 & 32          1
# 21 & ?           1
# 50 & 30          1
# Name: Age, Length: 157, dtype: int64

# %%
age = dict(df['Age'].value_counts())

# %%
sorted(age.items())
#checking the full list of ages.
# Out:
# [(' ', 2),
#  ('  ', 1),
#  (' 28', 1),
#  (' 30', 1),
#  (' 43', 1),
#  ('"middle-age"', 1),
#  ('"young"', 1),
#  ('(adult)', 1),
#  ('1', 2),
#  ('10', 56),
#  ('10 or 12', 1),
#  ('11', 37),
#  ('12', 72),
#  ('12 or 13', 1),
#  ('13', 94),
#  ('13 or 14', 1),
#  ('13 or 18', 1),
#  ('14', 101),
#  ('15', 139),
#  ('16', 138),
#  ('16 to 18', 1),
#  ('17', 154),
#  ('17 & 16', 1),
#  ('17 & 35', 1),
#  ('18', 150),
#  ('18 months', 1),
#  ('18 or 20', 1),
#  ('18 to 22', 1),
#  ('19', 142),
#  ('2 to 3 months', 1),
#  ('20', 141),
#  ('20 ', 1),
#  ('20?', 1),
#  ('20s', 7),
#  ('21', 119),
#  ('21 & ?', 1),
#  ('21 or 26', 1),
#  ('21, 34,24 & 35', 1),
#  ('22', 117),
#  ('23', 80),
#  ('23 & 20', 1),
#  ('23 & 26', 1),
#  ('24', 106),
#  ('25', 108),
#  ('25 or 28', 1),
#  ('25 to 35', 1),
#  ('26', 83),
#  ('27', 78),
#  ('28', 80),
#  ('28 & 26', 1),
#  ('28, 23 & 30', 1),
#  ('29', 77),
#  ('2�', 1),
#  ('3', 5),
#  ('30', 76),
#  ('30 & 32', 1),
#  ('30 or 36', 1),
# ...

# %%
df.to_csv('attacks_to_refine.csv')
#to avoid replacing all of them manually again, I'm exporting it to do it with open refine

# %%
df = pd.read_csv('attacks_refined.csv')
#We import it again after cleaning it with OpenRefine. 
#We cleaned other columns in the process. This should have been done at the very beginning

# %%
df.set_index('original order', inplace=True)
#we have to set the index again

# %%
df['Age'].value_counts()
# Out:
# 17           154
# 15           153
# 18           150
# 20           143
# 19           143
#             ...
# mid-30s        1
# 12 or 13       1
# mid-20s        1
# 18 months      1
# 50 & 30        1
# Name: Age, Length: 135, dtype: int64

# %%
age = dict(df['Age'].value_counts())

# %%
sorted(age.items())
#we check the data angain and we see there are many values that have "or", "&" and "to".
# Out:
# [('"middle-age"', 1),
#  ('1', 2),
#  ('10', 56),
#  ('10 or 12', 1),
#  ('11', 37),
#  ('12', 72),
#  ('12 or 13', 1),
#  ('13', 94),
#  ('13 or 14', 1),
#  ('13 or 18', 1),
#  ('14', 102),
#  ('15', 153),
#  ('16', 138),
#  ('16 to 18', 1),
#  ('17', 154),
#  ('17 & 16', 1),
#  ('17 & 35', 1),
#  ('18', 150),
#  ('18 months', 1),
#  ('18 or 20', 1),
#  ('18 to 22', 1),
#  ('19', 143),
#  ('2 to 3 months', 1),
#  ('20', 143),
#  ('20s', 7),
#  ('21', 120),
#  ('21 or 26', 1),
#  ('21, 34,24 & 35', 1),
#  ('22', 117),
#  ('23', 80),
#  ('23 & 20', 1),
#  ('23 & 26', 1),
#  ('24', 106),
#  ('25', 108),
#  ('25 or 28', 1),
#  ('25 to 35', 1),
#  ('26', 83),
#  ('27', 78),
#  ('28', 81),
#  ('28 & 26', 1),
#  ('28, 23 & 30', 1),
#  ('29', 77),
#  ('2�', 1),
#  ('3', 5),
#  ('30', 77),
#  ('30 or 36', 1),
#  ('30s', 6),
#  ('31', 54),
#  ('31 or 33', 1),
#  ('32', 68),
#  ('33', 44),
#  ('33 & 26', 1),
#  ('33 & 37', 1),
#  ('33 or 37', 1),
#  ('34', 50),
#  ('34 & 19', 1),
# ...

# %%
df['Age'] = df['Age'].astype('str')

# %%
df['Age'] = df['Age'].apply(lambda x: x.split(' or ')[0] if 'or' in x else x).apply(lambda x: x.split(' & ')[0] if '&' in x else x).apply(lambda x: x.split(' to ')[0] if 'to' in x else x).apply(lambda x: x.split('s')[0] if 's' in x else x)
#we use a function to obtain the values of the ages that have "or", "&" or "to" in them.

# %%
df['Age'].value_counts()
# Out:
# nan                2823
# 17                  156
# 15                  153
# 18                  152
# 20                  150
#                    ...
# 9 month               1
# MAKE LINE GREEN       1
# A.M.                  1
# Teen                  1
# 2                     1
# Name: Age, Length: 103, dtype: int64

# %%
age = dict(df['Age'].value_counts())

# %%
sorted(age.items())
#we check to see if it worked
# Out:
# [('"middle-age"', 1),
#  ('1', 2),
#  ('10', 57),
#  ('11', 37),
#  ('12', 73),
#  ('13', 96),
#  ('14', 102),
#  ('15', 153),
#  ('16', 139),
#  ('17', 156),
#  ('18', 152),
#  ('18 month', 1),
#  ('19', 143),
#  ('2', 1),
#  ('20', 150),
#  ('21', 121),
#  ('21, 34,24', 1),
#  ('22', 117),
#  ('23', 82),
#  ('24', 106),
#  ('25', 110),
#  ('26', 83),
#  ('27', 78),
#  ('28', 82),
#  ('28, 23', 1),
#  ('29', 77),
#  ('2�', 1),
#  ('3', 5),
#  ('30', 84),
#  ('31', 55),
#  ('32', 68),
#  ('33', 47),
#  ('34', 51),
#  ('35', 69),
#  ('36', 45),
#  ('37', 41),
#  ('37, 67, 35, 27,  ?', 1),
#  ('38', 48),
#  ('39', 38),
#  ('40', 59),
#  ('41', 38),
#  ('42', 38),
#  ('43', 44),
#  ('44', 29),
#  ('45', 33),
#  ('46', 28),
#  ('47', 30),
#  ('48', 28),
#  ('49', 28),
#  ('5', 7),
#  ('50', 37),
#  ('51', 20),
#  ('52', 35),
#  ('53', 13),
#  ('54', 17),
#  ('55', 23),
#  ('56', 10),
#  ('57', 16),
#  ('58', 15),
#  ('59', 11),
#  ('6', 14),
#  ('60', 16),
#  ('61', 13),
#  ('62', 8),
# ...

# %%
df['Age'] = df['Age'].apply(lambda x: int(x) if x.isnumeric() else 0).astype('int')
#finally we replace the remaining values with 0 to avoid doing a lot of manual cleaning like we did with the Countries

# %%
df['Age'].fillna(0)
# Out:
# original order
# 6303    57
# 6302    11
# 6301    48
# 6300     0
# 6299     0
#         ..
# 6        0
# 5        0
# 4        0
# 3        0
# 2       15
# Name: Age, Length: 6285, dtype: int32

# %%
age = dict(df['Age'].value_counts())

# %%
age
#all clean!
# Out:
# {0: 2848,
#  17: 156,
#  15: 153,
#  18: 152,
#  20: 150,
#  19: 143,
#  16: 139,
#  21: 121,
#  22: 117,
#  25: 110,
#  24: 106,
#  14: 102,
#  13: 96,
#  30: 84,
#  26: 83,
#  28: 82,
#  23: 82,
#  27: 78,
#  29: 77,
#  12: 73,
#  35: 69,
#  32: 68,
#  40: 59,
#  10: 57,
#  31: 55,
#  34: 51,
#  38: 48,
#  33: 47,
#  36: 45,
#  43: 44,
#  37: 41,
#  42: 38,
#  41: 38,
#  39: 38,
#  50: 37,
#  11: 37,
#  9: 37,
#  52: 35,
#  45: 33,
#  47: 30,
#  8: 29,
#  44: 29,
#  48: 28,
#  49: 28,
#  46: 28,
#  7: 24,
#  55: 23,
#  51: 20,
#  54: 17,
#  57: 16,
#  60: 16,
#  58: 15,
#  6: 14,
#  61: 13,
#  53: 13,
#  59: 11,
#  69: 10,
#  56: 10,
#  63: 9,
#  62: 8,
#  68: 7,
#  5: 7,
#  65: 7,
#  70: 6,
#  3: 5,
#  64: 4,
#  66: 4,
#  77: 3,
#  71: 3,
#  73: 3,
#  75: 2,
#  1: 2,
#  78: 2,
#  74: 2,
#  67: 1,
#  2: 1,
#  72: 1,
#  84: 1,
#  81: 1,
#  86: 1,
#  82: 1,
#  87: 1}

# %% [markdown]
# # Cleaning the Year column

# %%
df['Year'].describe()
# Out:
# count    6283.000000
# mean     1927.170301
# std       281.480602
# min         0.000000
# 25%      1942.000000
# 50%      1977.000000
# 75%      2005.000000
# max      2018.000000
# Name: Year, dtype: float64

# %%
df['Year'].value_counts()
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    126
#          ...
# 1767.0      1
# 1816.0      1
# 1812.0      1
# 1822.0      1
# 1748.0      1
# Name: Year, Length: 249, dtype: int64

# %%
year = dict(df['Year'].value_counts())

# %%
sorted(year.items())
# Out:
# [(0.0, 125),
#  (5.0, 1),
#  (77.0, 1),
#  (500.0, 1),
#  (1543.0, 1),
#  (1554.0, 1),
#  (1555.0, 1),
#  (1580.0, 1),
#  (1595.0, 1),
#  (1617.0, 1),
#  (1637.0, 1),
#  (1638.0, 1),
#  (1642.0, 2),
#  (1700.0, 3),
#  (1703.0, 1),
#  (1721.0, 1),
#  (1723.0, 1),
#  (1733.0, 1),
#  (1738.0, 1),
#  (1742.0, 1),
#  (1748.0, 1),
#  (1749.0, 1),
#  (1751.0, 1),
#  (1753.0, 1),
#  (1755.0, 1),
#  (1758.0, 1),
#  (1764.0, 1),
#  (1767.0, 1),
#  (1771.0, 1),
#  (1776.0, 2),
#  (1779.0, 1),
#  (1780.0, 1),
#  (1783.0, 1),
#  (1784.0, 1),
#  (1785.0, 1),
#  (1786.0, 1),
#  (1787.0, 1),
#  (1788.0, 1),
#  (1791.0, 1),
#  (1792.0, 1),
#  (1797.0, 1),
#  (1800.0, 1),
#  (1801.0, 1),
#  (1802.0, 1),
#  (1803.0, 2),
#  (1804.0, 1),
#  (1805.0, 1),
#  (1807.0, 1),
#  (1808.0, 3),
#  (1810.0, 1),
#  (1811.0, 1),
#  (1812.0, 1),
#  (1815.0, 1),
#  (1816.0, 1),
#  (1817.0, 4),
#  (1818.0, 1),
#  (1819.0, 1),
#  (1822.0, 1),
#  (1823.0, 1),
#  (1825.0, 2),
#  (1826.0, 5),
#  (1827.0, 3),
# ...

# %%
df['Year'] = df['Year'].fillna(0).astype('int')
#this column was pretty clean already

# %% [markdown]
# # Cleaning the Activity column

# %%
df['Activity'].describe()
# Out:
# count        5741
# unique       1396
# top       Surfing
# freq         1179
# Name: Activity, dtype: object

# %%
df['Activity'].value_counts()
# Out:
# Surfing                                   1179
# Swimming                                  1085
# Fishing                                    474
# Spearfishing                               338
# Diving                                     297
#                                           ...
# Scuba diving (ascending using scooter)       1
# Hand feeding sharks                          1
# Water-skiing                                 1
# preparing to go skin diving                  1
# Standing / Wading                            1
# Name: Activity, Length: 1396, dtype: int64

# %%
df['Activity'] = df['Activity'].astype('str')

# %%
#we group together all the activities that are similar
df['Activity'] = df['Activity'].apply(lambda x: 'Swimming' if 'swimming' in x.lower() or 'floating' in x.lower() or 'bath' in x.lower() or 'standing' in x.lower() or 'snorkeling' in x.lower() or 'treading' in x.lower() or 'wading' in x.lower() or 'walking' in x.lower() or 'play' in x.lower() or 'splashing' in x.lower() or 'wash' in x.lower() or 'shell' in x.lower() else x)
df['Activity'] = df['Activity'].apply(lambda x: 'Fishing' if 'fishing' in x.lower() or 'hunt' in x.lower() or 'spear' in x.lower() or 'net' in x.lower() or 'catch' in x.lower() or 'clam' in x.lower() or 'crab' in x.lower() else x)
df['Activity'] = df['Activity'].apply(lambda x: 'Diving' if 'diving' in x.lower() or 'dive' in x.lower() else x)
df['Activity'] = df['Activity'].apply(lambda x: 'Surfing' if 'surfing' in x.lower() or 'surf' in x.lower() or 'paddl' in x.lower() or 'ski' in x.lower() else x)
df['Activity'] = df['Activity'].apply(lambda x: 'Shipwreck' if 'accident' in x.lower() or 'disaster' in x.lower() or 'capsized' in x.lower() or 'wreck' in x.lower() or 'sank' in x.lower() or 'sink' in x.lower() else x)
df['Activity'] = df['Activity'].apply(lambda x: 'Kayaking' if 'kayak' in x.lower() or 'canoe' in x.lower() or 'rowing' in x.lower() or 'swamp' in x.lower()else x)
df['Activity'] = df['Activity'].apply(lambda x: 'Sailing' if 'sailing' in x.lower() or 'boating' in x.lower() else x)

# %%
#We replace the remaining ones with Other
df['Activity'] = df['Activity'].apply(lambda x: x if x == 'Swimming' or x == 'Fishing' or x == 'Diving' or x == 'Surfing' or x == 'Shipwreck' or x == 'Kayaking' or x == 'Sailing' else 'Other')

# %%
df['Activity'].value_counts()
# Out:
# Swimming     1913
# Surfing      1329
# Fishing      1151
# Other        1037
# Diving        557
# Shipwreck     147
# Kayaking       89
# Sailing        62
# Name: Activity, dtype: int64

# %% [markdown]
# # Cleaning the Species column

# %%
df.rename(columns = {'Species ':'Species'}, inplace = True)
#renaimg to remove the whitespace

# %%
df['Species'].describe()
# Out:
# count      3448
# unique     1202
# top       Shark
# freq        444
# Name: Species, dtype: object

# %%
df['Species'].value_counts()
# Out:
# Shark                                                 444
# White shark                                           391
# Tiger shark                                           111
# Shark involvement prior to death was not confirmed    105
# Invalid                                               102
#                                                      ...
# Caribbean reef shark, 7' to 8'                          1
# Shovelnose shark, 5'                                    1
# White shark, 7m                                         1
# Grey nurse shark, 2.9 m [9'6"]                          1
# 1.2 m [4'] hammerhead shark                             1
# Name: Species, Length: 1202, dtype: int64

# %%
df['Species'].fillna('Unknown', inplace = True)

# %%
df['Species'].value_counts()
# Out:
# Unknown                                               2838
# Shark                                                  444
# White shark                                            391
# Tiger shark                                            111
# Shark involvement prior to death was not confirmed     105
#                                                       ...
# Caribbean reef shark, 7' to 8'                           1
# Shovelnose shark, 5'                                     1
# White shark, 7m                                          1
# Grey nurse shark, 2.9 m [9'6"]                           1
# 1.2 m [4'] hammerhead shark                              1
# Name: Species, Length: 1202, dtype: int64

# %%
df['Species'] = df['Species'].astype(str)

# %%
species = dict(df['Species'].value_counts())

# %%
species
# Out:
# {'Unknown': 2838,
#  'Shark': 444,
#  'White shark': 391,
#  'Tiger shark': 111,
#  'Shark involvement prior to death was not confirmed': 105,
#  'Invalid': 102,
#  'Shark involvement not confirmed': 89,
#  'Bull shark': 68,
#  'Shark involvement prior to death unconfirmed': 67,
#  "6' shark": 40,
#  'Questionable incident': 37,
#  'Questionable': 34,
#  'Nurse shark': 31,
#  'Wobbegong shark': 27,
#  'Blacktip shark': 26,
#  "5' shark": 26,
#  "4' to 5' shark": 24,
#  'Spinner shark': 21,
#  'No shark involvement': 20,
#  "3' to 4' shark": 18,
#  'Blue shark': 16,
#  "3.7 m [12'] shark": 16,
#  'Zambesi shark': 15,
#  'Bronze whaler shark': 15,
#  "12' shark": 15,
#  'Mako shark': 14,
#  'Reef shark': 14,
#  'Raggedtooth shark': 14,
#  'Shark involvement prior to death not confirmed': 13,
#  "7' shark": 13,
#  "10' shark": 12,
#  'Hammerhead shark': 12,
#  'Sandtiger shark': 11,
#  'Sand shark': 11,
#  "2.1 m [7'] shark": 9,
#  "2' to 3' shark": 8,
#  'Lemon shark': 8,
# ...

# %%
df.drop(index=df[df['Species'].apply(lambda x: 'no shark' in x.lower() or 'not confirmed' in x.lower() or 'unconfirmed' in x.lower())].index, inplace=True)
#dropping the lines which have one of these as species since they're not shark attacks after all

# %%
df[df['Species'].apply(lambda x: 'no shark' in x.lower() or 'not confirmed' in x.lower() or 'unconfirmed' in x.lower())]
#checking they are dropped
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal, Time, Species, Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 23 columns]

# %%
species = dict(df['Species'].value_counts())

# %%
species
# Out:
# {'Unknown': 2838,
#  'Shark': 444,
#  'White shark': 391,
#  'Tiger shark': 111,
#  'Invalid': 102,
#  'Bull shark': 68,
#  "6' shark": 40,
#  'Questionable incident': 37,
#  'Questionable': 34,
#  'Nurse shark': 31,
#  'Wobbegong shark': 27,
#  "5' shark": 26,
#  'Blacktip shark': 26,
#  "4' to 5' shark": 24,
#  'Spinner shark': 21,
#  "3' to 4' shark": 18,
#  "3.7 m [12'] shark": 16,
#  'Blue shark': 16,
#  'Zambesi shark': 15,
#  'Bronze whaler shark': 15,
#  "12' shark": 15,
#  'Reef shark': 14,
#  'Raggedtooth shark': 14,
#  'Mako shark': 14,
#  "7' shark": 13,
#  'Hammerhead shark': 12,
#  "10' shark": 12,
#  'Sandtiger shark': 11,
#  'Sand shark': 11,
#  "2.1 m [7'] shark": 9,
#  'Lemon shark': 8,
#  "2' to 3' shark": 8,
#  "9' shark": 7,
#  "Tiger shark, 10'": 7,
#  '2.5 m shark': 7,
#  'Sharks': 7,
#  "Bull shark, 6'": 7,
#  "8' shark": 7,
#  'Basking shark': 7,
#  "6' to 8' shark": 7,
#  'Oceanic whitetip shark': 7,
#  '1.8 m shark': 7,
#  "14' shark": 6,
# ...

# %%
df['Species'] = df['Species'].apply(lambda x: 'Unknown/Other' if 'shark' not in x.lower() or x.lower() == 'shark' else x)
df['Species'] = df['Species'].apply(lambda x: 'White shark' if 'white' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Tiger shark' if 'tiger' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Bull shark' if 'bull' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Nurse shark' if 'nurse' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Wobbegong shark' if 'wobbegong' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Blacktip shark' if 'blacktip' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Spinner shark' if 'spinner' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Blue shark' if 'blue' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Bronze whaler shark' if 'whaler' in x.lower() or 'copper' in x.lower() or 'narrowtooth' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Zambesi shark' if 'zambesi' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Raggedtooth shark' if 'raggedtooth' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Mako shark' if 'mako' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Reef shark' if 'reef' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Hammerhead shark' if 'hammer' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Sand shark' if 'sand shark' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Sandtiger shark' if 'sandtiger' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Lemon shark' if 'lemon' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Oceanic whitetip shark' if 'whitetip' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Basking shark' if 'basking' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Sevengill shark' if 'sevengill' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Galapagos shark' if 'galapagos' in x.lower() else x)
df['Species'] = df['Species'].apply(lambda x: 'Angel shark' if 'angel' in x.lower() else x)
#we find and clean the main species

# %%
df['Species'] = df['Species'].apply(lambda x: x if 'White shark' in x or 'Tiger shark' in x or 'Bull shark' in x or 'Nurse shark' in x or 'Wobbegong shark' in x or 'Blacktip shark' in x or 'Spinner shark' in x or 'Blue shark' in x or 'Bronze whaler shark' in x or 'Zambesi shark' in x or 'Raggedtooth shark' in x or 'Mako shark' in x or 'Reef shark' in x or 'Hammerhead shark' in x or 'Sand shark' in x or 'Sandtiger shark' in x or 'Lemon shark' in x or 'Oceanic whitetip shark' in x or 'Basking shark' in x or 'Sevengill shark' in x or 'Galapagos shark' in x or 'Angel shark' in x else 'Unknown/Other')
#If it's not one of the main species, we replace it with 'Unknown/Other'

# %%
species = dict(df['Species'].value_counts())

# %%
species
#all clean!
# Out:
# {'Unknown/Other': 4161,
#  'White shark': 661,
#  'Tiger shark': 282,
#  'Bull shark': 177,
#  'Nurse shark': 97,
#  'Blacktip shark': 85,
#  'Bronze whaler shark': 72,
#  'Reef shark': 54,
#  'Mako shark': 54,
#  'Blue shark': 46,
#  'Wobbegong shark': 46,
#  'Hammerhead shark': 45,
#  'Raggedtooth shark': 40,
#  'Lemon shark': 34,
#  'Spinner shark': 32,
#  'Zambesi shark': 29,
#  'Sand shark': 18,
#  'Sevengill shark': 15,
#  'Basking shark': 7,
#  'Galapagos shark': 7,
#  'Angel shark': 6}

# %% [markdown]
# # Dropping unnecessary columns & exporting

# %%
with pd.option_context('display.max_rows', 5, 'display.max_columns', None): 
    display(df)
# Out:
#                Case Number         Date  Year        Type    Country  \
# original order
# 6303            2018.06.25  25-Jun-2018  2018     Boating        USA
# 6302            2018.06.18  18-Jun-2018  2018  Unprovoked        USA
# ...                    ...          ...   ...         ...        ...
# 3                  ND.0002    1883-1889     0  Unprovoked     PANAMA
# 2                  ND.0001    1845-1853     0  Unprovoked  SRI LANKA
#
#                             Area                             Location  \
# original order
# 6303                  California          Oceanside, San Diego County
# 6302                     Georgia       St. Simon Island, Glynn County
# ...                          ...                                  ...
# 3                            NaN                 Panama Bay 8�N, 79�W
# 2               Eastern Province  Below the English fort, Trincomalee
#
#                 Activity             Name Sex  Age  \
# original order
# ...

# %%
df.drop(['Date', 'Type', 'Area', 'Location', 'Name', 'Injury', 'Time', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'Unnamed: 22', 'Unnamed: 23'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5968 entries, 6303 to 2
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Case Number  5967 non-null   object
#  1   Year         5968 non-null   int32
#  2   Country      5968 non-null   object
#  3   Activity     5968 non-null   object
#  4   Sex          5968 non-null   object
#  5   Age          5968 non-null   int32
#  6   Fatal        5968 non-null   object
#  7   Species      5968 non-null   object
# dtypes: int32(2), object(6)
# memory usage: 373.0+ KB

# %%
df.to_csv('attacks_clean.csv')

# %% [markdown]
# # Analysis & visualization

# %% [markdown]
# ## Top 10 countries with the most attacks

# %%
df['Country'].value_counts()[:10]
# Out:
# USA                 2095
# AUSTRALIA           1263
# SOUTH AFRICA         541
# PAPUA NEW GUINEA     134
# NEW ZEALAND          123
# BAHAMAS              107
# BRAZIL               104
# MEXICO                85
# ITALY                 67
# FIJI                  64
# Name: Country, dtype: int64

# %%
df['Country'].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Attacks by sex

# %%
df['Sex'].value_counts()
# Out:
# M          4851
# F           597
# Unknown     520
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Attacks by species

# %%
df['Species'].value_counts()[:10]
# Out:
# Unknown/Other          4161
# White shark             661
# Tiger shark             282
# Bull shark              177
# Nurse shark              97
# Blacktip shark           85
# Bronze whaler shark      72
# Reef shark               54
# Mako shark               54
# Blue shark               46
# Name: Species, dtype: int64

# %%
df['Species'].value_counts()[:10].plot(kind='bar')
#most of the species are unknown, so we want to drop this column to see the other more clearly
# Out:
# <AxesSubplot:>

# %%
known_species = df.drop(index=df[df['Species'].apply(lambda x: 'Unknown/Other' in x)].index)
#we create a new df with only the known species

# %%
known_species['Species'].value_counts()[:10]
# Out:
# White shark            661
# Tiger shark            282
# Bull shark             177
# Nurse shark             97
# Blacktip shark          85
# Bronze whaler shark     72
# Mako shark              54
# Reef shark              54
# Blue shark              46
# Wobbegong shark         46
# Name: Species, dtype: int64

# %%
known_species['Species'].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Deadly attacks

# %%
df['Fatal'].value_counts()
# Out:
# N          4282
# Y          1380
# UNKNOWN     306
# Name: Fatal, dtype: int64

# %%
5968 0.7

# %%
df['Fatal'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Attacks by age

# %%
df['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
age = df.drop(index=df[df['Age'].apply(lambda x: x == 0)].index)
#we drop the 0s because they are unknown ages

# %%
age['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Attacks over the years

# %%
df['Year'].value_counts()
# Out:
# 2015    133
# 2017    129
# 0       127
# 2016    124
# 2011    119
#        ...
# 1786      1
# 1758      1
# 1742      1
# 1738      1
# 1554      1
# Name: Year, Length: 245, dtype: int64

# %%
df['Year'].hist()
# Out:
# <AxesSubplot:>

# %%
years = df.drop(index=df[df['Year'].apply(lambda x: x < 1900)].index)
#we drop all the years before 1900 because we have very little data and it's hard to see the evolution

# %%
years['Year'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Attacks by activity

# %%
df['Activity'].value_counts()
# Out:
# Swimming     1822
# Surfing      1295
# Fishing      1121
# Other         922
# Diving        537
# Shipwreck     127
# Kayaking       89
# Sailing        55
# Name: Activity, dtype: int64

# %%
df['Activity'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
