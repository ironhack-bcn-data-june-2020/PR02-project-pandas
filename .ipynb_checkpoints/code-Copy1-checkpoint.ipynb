# %% [markdown]
# # Importamos librerías y el dataframe

# %%
import pandas as pd
import numpy as np
from datetime import *
import re

# %%
df = pd.read_csv('/Users/Júlia/Documents/Ironhack/modulo_1/Proyectos/PR02-project-pandas/attacks.csv')

# %%
df.head(5)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# # Observamos las características del dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
with pd.option_context('display.max_rows', 10, 'display.max_columns', None): 
    display(df)
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
#df[['Type', 'Country', 'Area', 'Activity', 'Fatal (Y/N)', 'Sex ', 'Species ']] = df[['Type', 'Country', 'Area', 'Activity', 'Fatal (Y/N)', 'Sex ', 'Species ']].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
#df.drop(['pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'Unnamed: 22', 'Unnamed: 23'], axis = 1, inplace=True)

# %%
with pd.option_context('display.max_rows', 10, 'display.max_columns', None): 
    display(df)
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.dropna(how='all', thresh=3, inplace=True)

# %%
with pd.option_context('display.max_rows', 10, 'display.max_columns', None): 
    display(df)
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
#pd.to_datetime(df['Date'])
df['Date'] = df['Case Number'].apply(lambda x: '-'.join(str(x).split('.')[0:3]))

# %%
with pd.option_context('display.max_rows', 5, 'display.max_columns', None): 
    display(df)
# Out:
#      Case Number        Date    Year        Type             Country  \
# 0     2018.06.25  2018-06-25  2018.0     Boating                 USA
# 1     2018.06.18  2018-06-18  2018.0  Unprovoked                 USA
# ...          ...         ...     ...         ...                 ...
# 6300     ND.0002     ND-0002     0.0  Unprovoked              PANAMA
# 6301     ND.0001     ND-0001     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   Area                             Location  Activity  \
# 0           California          Oceanside, San Diego County  Paddling
# 1              Georgia       St. Simon Island, Glynn County  Standing
# ...                ...                                  ...       ...
# 6300               NaN                 Panama Bay 8�N, 79�W       NaN
# 6301  Eastern Province  Below the English fort, Trincomalee  Swimming
#
#                  Name Sex   Age  \
# 0         Julie Wolfe    F   57
# 1     Adyson�McNeely     F   11
# ...

# %%
df['Date'] = df['Date_OK'].astype()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0250185d7dce> in <module>
# ----> 1 df['Date'] = df['Date_OK'].astype()
#
# NameError: name 'df' is not defined

# %%
#indice usar original order: len(df['original order'].unique()) con esto tenemos el índice
#en la columna nombre podemos sacar male y female para rellenar donde falta el sexo 
#df['Case Number'].str.findall('(\d{4}\.\d{2}\.\d{2})').str.join('') para la fecha
#clustering de palabras con openrefine. interesante para hacer clusters

# %%
df['Activity'].fillna('').apply(lambda x: 'Swimming' if ('Swimming' in x) else '').head(10)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6    Swimming
# 7
# 8
# 9
# Name: Activity, dtype: object

# %%
df['Species '].value_counts().head(12)
# Out:
# White shark                                           163
# Shark involvement prior to death was not confirmed    105
# Invalid                                               102
# Shark involvement not confirmed                        88
# Tiger shark                                            73
# Shark involvement prior to death unconfirmed           68
# Bull shark                                             52
# 6' shark                                               40
# 4' shark                                               40
# 1.8 m [6'] shark                                       35
# Questionable incident                                  35
# Questionable                                           34
# Name: Species , dtype: int64

# %%
import re

# %%
df['Species '].str.findall('((?:\w{3,} )?[s|S]hark)').str.join('').str.lower().value_counts().head(30)
# Out:
# shark                1225
# white shark           621
# tiger shark           256
#                       241
# bull shark            166
# nurse shark            95
# whaler shark           65
# reef shark             63
# blacktip shark         59
# small shark            55
# mako shark             51
# wobbegong shark        46
# hammerhead shark       43
# raggedtooth shark      43
# blue shark             38
# spinner shark          38
# lemon shark            33
# zambesi shark          29
# whitetip shark         20
# sandtiger shark        20
# sand shark             16
# sevengill shark        11
# dusky shark            10
# carpet shark            8
# basking shark           7
# galapagos shark         7
# gill shark              7
# porbeagle shark         6
# colored shark           6
# dog shark               6
# Name: Species , dtype: int64

# %%
df[['Sex ', 'Name']]
# Out:
#       Sex              Name
# 0        F      Julie Wolfe
# 1        F  Adyson�McNeely
# 2        M      John Denges
# 3        M             male
# 4        M   Gustavo Ramos
# ...    ...              ...
# 25718  NaN              NaN
# 25719  NaN              NaN
# 25720  NaN              NaN
# 25721  NaN              NaN
# 25722  NaN              NaN
#
# [25723 rows x 2 columns]

# %%
df[df['Sex '].isna()][df.Name.isin(['male', 'female'])][['Sex ', 'Name']].head(10)
# Out:
# <ipython-input-33-375b3c3efdfd>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Sex '].isna()][df.Name.isin(['male', 'female'])][['Sex ', 'Name']].head(10)
#      Sex   Name
# 2225  NaN  male
# 3049  NaN  male
# 3452  NaN  male
# 4338  NaN  male
# 4467  NaN  male
# 6062  NaN  male
# 6108  NaN  male

# %%
df.loc[df[df['Sex '].isna()][df.Name.isin(['male', 'female'])][['Sex ', 'Name']].index, 'Sex '] = df[df['Sex '].isna()][df.Name.isin(['male', 'female'])][['Sex ', 'Name']]
#reemplazamos los que no tienen sexo y lo tienen en el nombre
# Out:
# <ipython-input-34-4cf312c8c890>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[df[df['Sex '].isna()][df.Name.isin(['male', 'female'])][['Sex ', 'Name']].index, 'Sex '] = df[df['Sex '].isna()][df.Name.isin(['male', 'female'])][['Sex ', 'Name']]

# %%
#ver los clusters de locations con openrefine. Ver clase del jueves 18/3 a las 20h aprox

# %%
df[df.Date.str.startswith('Early').fillna(False)]['Date'].str.findall('(?:\w{3}-)?\d{4}')
# Out:
# 1448    [Aug-2006]
# 2017    [Sep-2000]
# 2053    [Jun-2000]
# 2375    [Jul-1995]
# 3063    [Jul-1980]
# 3277    [Feb-1974]
# 3546    [Nov-1966]
# 3644        [1965]
# 3774        [1963]
# 4026        [1960]
# 5562        [1900]
# 5918        [1870]
# 6276        [1930]
# Name: Date, dtype: object

# %%
import re

# %%
nombre = 'JuanMariaLopez'

# %%
re.split('[A-Z]', nombre)
# Out:
# ['', 'uan', 'aria', 'opez']

# %%
re.split('(?=[A-Z])', nombre)
# Out:
# ['', 'Juan', 'Maria', 'Lopez']

# %%
re.split('(?<=[a-z])(?=[A-Z])', nombre)
# Out:
# ['Juan', 'Maria', 'Lopez']
